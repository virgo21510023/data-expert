# %% [markdown]
# <a href="https://colab.research.google.com/github/virgo21510023/data-expert/blob/main/Latihan_Logistic_Regression_Menggunakan_data_social_ads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/Social_Network_Ads.csv')
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data = df.drop(columns=['User ID'])
data = pd.get_dummies(data)
data
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Female  Gender_Male
# 0     19            19000          0          False         True
# 1     35            20000          0          False         True
# 2     26            43000          0           True        False
# 3     27            57000          0           True        False
# 4     19            76000          0          False         True
# ..   ...              ...        ...            ...          ...
# 395   46            41000          1           True        False
# 396   51            23000          1          False         True
# 397   50            20000          1           True        False
# 398   36            33000          0          False         True
# 399   49            36000          1           True        False
#
# [400 rows x 5 columns]

# %%
#pisah atribut label

predictions = ['Age' , 'EstimatedSalary' , 'Gender_Female' , 'Gender_Male']
X = data[predictions]
y = data['Purchased']

# %%
#melakukan normalisasi terhadap data yg dimiliki
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
scaled_data = scaler.transform(X)
scaled_data = pd.DataFrame(scaled_data, columns= X.columns)

# %%
#membagi data menjadi train set dan test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_data, y, test_size=0.2, random_state=1)

# %%
#melatih model
from sklearn import linear_model
model = linear_model.LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#uji tingkat akurasi model
model.score(X_test, y_test)
# Out:
# 0.825
